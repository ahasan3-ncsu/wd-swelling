# %% [markdown]
# # SALib

# %%
import numpy as np
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami

# %%
pi = 3.14159265359

problem = {
    'num_vars': 3,
    'names': ['x1', 'x2', 'x3'],
    'bounds': [[-pi, pi], [-pi, pi], [-pi,pi]]
}

# %%
param_values = saltelli.sample(problem, 1024)
# Out:
# /tmp/ipykernel_27955/1862108280.py:1: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, 1024)

# %%
param_values.shape
# Out:
# (8192, 3)

# %%
Y = Ishigami.evaluate(param_values)

# %%
Si = sobol.analyze(problem, Y, print_to_console=True)
# Out:
#           ST   ST_conf
# x1  0.555860  0.091587
# x2  0.441898  0.041798
# x3  0.244675  0.029986
#           S1   S1_conf
# x1  0.316832  0.054187
# x2  0.443763  0.058715
# x3  0.012203  0.055719
#                 S2   S2_conf
# (x1, x2)  0.009254  0.080589
# (x1, x3)  0.238172  0.095322
# (x2, x3) -0.004888  0.071592
# /home/atom/research/wd-swelling/.swel/lib/python3.12/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
print(Si['S1'])
# Out:
# [0.31683154 0.44376306 0.01220312]

# %%
print(Si['ST'])
# Out:
# [0.55586009 0.44189807 0.24467539]

# %%
Si.plot()
# Out:
# /home/atom/research/wd-swelling/.swel/lib/python3.12/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)
