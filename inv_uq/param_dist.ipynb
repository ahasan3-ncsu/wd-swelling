# %%
import pandas as pd

# %%
jar = pd.read_csv('clean_data.csv')

# %%
jar
# Out:
#        dGrainHBS  FaceCovMax  SwellLink        vResol  DatomFissGBx  \
# 0       0.000044     0.72468   0.022700  1.907300e-18       29013.0
# 1       0.000044     0.72468   0.022700  1.907300e-18       29013.0
# 2       0.000044     0.72468   0.022700  1.907300e-18       29013.0
# 3       0.000044     0.72468   0.022700  1.907300e-18       29013.0
# 4       0.000044     0.72468   0.022700  1.907300e-18       29013.0
# ...          ...         ...        ...           ...           ...
# 22395   0.000035     0.64653   0.029397  1.892700e-18       28796.0
# 22396   0.000035     0.64653   0.029397  1.892700e-18       28796.0
# 22397   0.000035     0.64653   0.029397  1.892700e-18       28796.0
# 22398   0.000035     0.64653   0.029397  1.892700e-18       28796.0
# 22399   0.000035     0.64653   0.029397  1.892700e-18       28796.0
#
#           fNucleate  aAtomDifFiss            FD  fuel_swelling  \
# 0      6.314700e-10  5.295700e-31  1.036800e+21         4.3648
# ...

# %%
jar.describe()
# Out:
#           dGrainHBS    FaceCovMax     SwellLink        vResol  DatomFissGBx  \
# count  22400.000000  22400.000000  22400.000000  2.240000e+04  22400.000000
# mean       0.000040      0.750734      0.025000  1.999994e-18  29999.759375
# std        0.000004      0.066660      0.002499  1.999026e-19   2998.302408
# min        0.000024      0.600150      0.016013  1.303400e-18  19641.000000
# 25%        0.000037      0.702355      0.023314  1.865075e-18  27977.250000
# 50%        0.000040      0.750435      0.025000  2.000000e-18  30000.000000
# 75%        0.000043      0.798700      0.026686  2.134750e-18  32022.250000
# max        0.000056      0.906520      0.034133  2.696100e-18  40530.000000
#
#           fNucleate  aAtomDifFiss            FD  fuel_swelling  \
# count  2.240000e+04  2.240000e+04  2.240000e+04   22400.000000
# mean   5.999965e-10  5.070039e-31  4.018843e+21      24.359638
# std    6.004245e-11  5.071823e-32  1.989794e+21      17.078681
# ...

# %%
import seaborn as sns

# %%
for i in range(7):
    sns.histplot(jar.iloc[:,i])
    plt.show()
