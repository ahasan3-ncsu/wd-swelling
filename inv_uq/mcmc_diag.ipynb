# %% [markdown]
# # Diagnostics

# %%
import numpy as np

# %%
hey1 = np.load('hey1.npy')

# %%
hey2 = np.load('hey2.npy')

# %%
import arviz as az

# %%
azdat = az.convert_to_inference_data(np.stack([hey1, hey2]))

# %%
azdat

# %%
azdat.posterior.coords

# %%
az.plot_trace(azdat)

# %%
az.plot_autocorr(azdat, max_lag=500)

# %%
az.ess(azdat)

# %%
az.ess(azdat)['x']

# %%
az.rhat(azdat)

# %%
az.rhat(azdat)['x']
