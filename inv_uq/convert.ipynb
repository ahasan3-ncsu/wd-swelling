# %%
with open('../data_2021/dakota/dart_results_tabular.dat', 'r') as f:
    jar = f.readlines()

# %%
jar[:10]
# Out:
# ['%eval_id interface FaceCovMax     rResolBulk     vResol         DatomFissGBx   fNucleate      aAtomDifFiss   StickProb      rResolGBB      fuel_swelling  fuel_gas_swelling \n',
#  '1        NO_ID      0.650871557    3.281528662e-09 5.696812621e-18 9720.560229    2.415274238e-09 5.4587482e-31  1.250136318e-07 6.908243157e-07 117.7925863    85.72090615    \n',
#  '2        NO_ID      0.7004889706   3.405614543e-09 2.270948299e-18 10617.11946    3.584054292e-10 5.298310102e-31 1.674882269e-07 9.826777456e-07 114.5628244    82.49114429    \n',
#  '3        NO_ID      0.7706605814   3.548509496e-09 1.371848679e-18 25422.01078    1.667373799e-10 3.316310037e-31 3.433259094e-07 3.038372675e-06 107.5209732    75.44929302    \n',
#  '4        NO_ID      0.683931201    3.364810439e-09 1.777367097e-18 8486.594548    1.579264888e-10 1.698032105e-30 1.423811074e-07 8.31258721e-07 40910.69804    40878.62636    \n',
# ...

# %%
jar[0].split()
# Out:
# ['%eval_id',
#  'interface',
#  'FaceCovMax',
#  'rResolBulk',
#  'vResol',
#  'DatomFissGBx',
#  'fNucleate',
#  'aAtomDifFiss',
#  'StickProb',
#  'rResolGBB',
#  'fuel_swelling',
#  'fuel_gas_swelling']

# %%
jar[1].split()
# Out:
# ['1',
#  'NO_ID',
#  '0.650871557',
#  '3.281528662e-09',
#  '5.696812621e-18',
#  '9720.560229',
#  '2.415274238e-09',
#  '5.4587482e-31',
#  '1.250136318e-07',
#  '6.908243157e-07',
#  '117.7925863',
#  '85.72090615']

# %%
len(jar[0].split())
# Out:
# 12

# %%
len(jar[1].split())
# Out:
# 12

# %%
for line in jar:
    tmp = line.split()
    s = ''
    for i in tmp[2:-1]:
        s += i + ','
    s += tmp[-1] + '\n'
    with open('ex.csv', 'a') as f:
        f.write(s)
